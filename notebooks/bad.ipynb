# %% [markdown]
# # BAD Notebook
# This notebook intentionally includes issues for lint testing.

# %%
from math import *  # not recommended

# %%
print('huge output below')
print('...')
# Out:
# huge output below
# ...

# %%
x = 42
x
# Out:
# 42

# %%
import sys
print('debug')
# Out:
# debug
